# %%
import numpy as np
import pandas as pd
from sklearn.manifold import TSNE, locally_linear_embedding
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# Download Two Reports and their word embeddings by BERT
# !wget https://box.hu-berlin.de/f/cbd7041e528a4652b2c1/?dl=1 -O "China Star_Sustainability Report.pkl"
# !wget https://box.hu-berlin.de/f/0f639732e5be43fd82d2/?dl=1 -O "Yongnam Annual Report 2010.pkl"

# Download Pretrained W2V
# !wget https://box.hu-berlin.de/f/8e012741d75b40dc88cb/?dl=1 -O "GoogleNews-vectors-negative300.bin.gz"
# Out:
# Warning: Failed to set locale category LC_NUMERIC to en_DE.
# Warning: Failed to set locale category LC_TIME to en_DE.
# Warning: Failed to set locale category LC_COLLATE to en_DE.
# Warning: Failed to set locale category LC_MONETARY to en_DE.
# Warning: Failed to set locale category LC_MESSAGES to en_DE.
# --2020-04-15 14:20:37--  https://box.hu-berlin.de/f/cbd7041e528a4652b2c1/?dl=1
# Resolving box.hu-berlin.de (box.hu-berlin.de)... 141.20.184.42
# Connecting to box.hu-berlin.de (box.hu-berlin.de)|141.20.184.42|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://box.hu-berlin.de/seafhttp/files/57156aa2-6fb0-4c04-b92b-71e521c6f7d3/Yongnam%20Annual%20Report%202010.pkl [following]
# --2020-04-15 14:20:37--  https://box.hu-berlin.de/seafhttp/files/57156aa2-6fb0-4c04-b92b-71e521c6f7d3/Yongnam%20Annual%20Report%202010.pkl
# Reusing existing connection to box.hu-berlin.de:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1216636 (1.2M) [application/octet-stream]
# Saving to: ‘China Star_Sustainability Report.pkl’
#
# China Star_Sustaina 100%[===================>]   1.16M  3.19MB/s    in 0.4s
#
# 2020-04-15 14:20:37 (3.19 MB/s) - ‘China Star_Sustainability Report.pkl’ saved [1216636/1216636]
#
# Warning: Failed to set locale category LC_NUMERIC to en_DE.
# Warning: Failed to set locale category LC_TIME to en_DE.
# Warning: Failed to set locale category LC_COLLATE to en_DE.
# Warning: Failed to set locale category LC_MONETARY to en_DE.
# Warning: Failed to set locale category LC_MESSAGES to en_DE.
# --2020-04-15 14:20:38--  https://box.hu-berlin.de/f/0f639732e5be43fd82d2/?dl=1
# Resolving box.hu-berlin.de (box.hu-berlin.de)... 141.20.184.42
# Connecting to box.hu-berlin.de (box.hu-berlin.de)|141.20.184.42|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://box.hu-berlin.de/seafhttp/files/f0e0d4bc-5608-44a2-a473-ea23c8dc439b/China%20Star_Sustainability%20Report.pkl [following]
# --2020-04-15 14:20:38--  https://box.hu-berlin.de/seafhttp/files/f0e0d4bc-5608-44a2-a473-ea23c8dc439b/China%20Star_Sustainability%20Report.pkl
# Reusing existing connection to box.hu-berlin.de:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1128466 (1.1M) [application/octet-stream]
# Saving to: ‘Yongnam Annual Report 2010.pkl’
#
# Yongnam Annual Repo 100%[===================>]   1.08M  3.22MB/s    in 0.3s
#
# 2020-04-15 14:20:38 (3.22 MB/s) - ‘Yongnam Annual Report 2010.pkl’ saved [1128466/1128466]

# %%
com1 = pd.read_pickle("China Star_Sustainability Report.pkl")
com2 = pd.read_pickle("Yongnam Annual Report 2010.pkl")

# %%
# com1 = com1[com1.punc==False]
# com1 = com1[com1.stopwords==False]
# com2 = com2[com2.punc==False]
# com2 = com2[com2.stopwords==False]

# %%
words = []
vectors = []
for i, word in enumerate(set(com1.token)):
    tm_df = com1[com1.token==word]
    tm_mat = np.matrix(tm_df.vector.to_list())
    tm_mat = tm_mat.mean(0)
    words.append(word)
    vectors.append(np.array(tm_mat)[0])

# %%
df1 = pd.DataFrame({'words':words, 'vector':vectors})

# %%
words2 = []
vectors2 = []
for i, word in enumerate(set(com2.token)):
    tm_df = com2[com2.token==word]
    tm_mat = np.matrix(tm_df.vector.to_list())
    tm_mat = tm_mat.mean(0)
    words2.append(word)
    vectors2.append(np.array(tm_mat)[0])

# %%
df2 = pd.DataFrame({'words':words2, 'vector':vectors2})

# %%
# prepare for plotting
lle = locally_linear_embedding(np.matrix(df1.vector.to_list()), n_components=2, n_neighbors=12)
lle = lle[0]
lle2 = locally_linear_embedding(np.matrix(df2.vector.to_list()), n_components=2, n_neighbors=12)
lle2 = lle2[0]

# %%
fig = plt.figure(figsize=(30, 30))
for i,t in enumerate(df1.words):
    x = lle[i,0]
    y = lle[i,1]
    plt.scatter(x, y, marker='o', color='red', s=180)
    plt.text(x+0.005, y+0.005, t, fontsize=13)
    
for i,t in enumerate(df2.words):
    x = lle2[i,0]
    y = lle2[i,1]
    plt.scatter(x, y, marker='o', color='blue', s=180)
    plt.text(x+0.005, y+0.005, t, fontsize=10)
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.title('Reduced to 2D using LLE')
plt.savefig('./LLE_BERT.png', transparent=True, facecolor=fig.get_facecolor())
plt.show()

# %%
from gensim.models.word2vec import Word2Vec
import gensim.downloader as api

# %%
model = api.load("glove-wiki-gigaword-50")

# %%
words3 = []
vectors3 = []
for i, word in enumerate(set(com1.token)):
    tm_df = com1[com1.token==word]
    words3.append(word)
    try:
        vectors3.append(model[word])
    except:
        vectors3.append([0]*50)

# %%
words4 = []
vectors4 = []
for i, word in enumerate(set(com2.token)):
    tm_df = com2[com2.token==word]
    words4.append(word)
    try:
        vectors4.append(model[word])
    except:
        vectors4.append([0]*50)

# %%
df3 = pd.DataFrame({'words':words3, 'vector':vectors3})
df4 = pd.DataFrame({'words':words4, 'vector':vectors4})

# %%
lle3 = locally_linear_embedding(np.matrix(df3.vector.to_list()), n_components=2, n_neighbors=12)
lle3 = lle3[0]
lle4 = locally_linear_embedding(np.matrix(df4.vector.to_list()), n_components=2, n_neighbors=12)
lle4 = lle4[0]

# %%
fig = plt.figure(figsize=(30, 30))
for i,t in enumerate(df3.words):
    x = lle3[i,0]
    y = lle3[i,1]
    plt.scatter(x, y, marker='o', color='red', s=180)
    plt.text(x+0.005, y+0.005, t, fontsize=13)
    
for i,t in enumerate(df4.words):
    x = lle4[i,0]
    y = lle4[i,1]
    plt.scatter(x, y, marker='o', color='blue',s=180)
    plt.text(x+0.005, y+0.005, t, fontsize=10)
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.title('Reduced to 2D using LLE')
plt.savefig('./LLE_glove.png', transparent=True)
plt.show()

# %%
from gensim.models.keyedvectors import KeyedVectors
model_w2v = KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin.gz', binary=True)
# model = Word2Vec.load('GoogleNews-vectors-negative300.bin.gz')

# %%
words5 = []
vectors5 = []
for i, word in enumerate(set(com1.token)):
    tm_df = com1[com1.token==word]
    words5.append(word)
    try:
        vectors5.append(model_w2v[word])
    except:
        vectors5.append([0]*300)

# %%
words6 = []
vectors6 = []
for i, word in enumerate(set(com2.token)):
    tm_df = com2[com2.token==word]
    words6.append(word)
    try:
        vectors6.append(model_w2v[word])
    except:
        vectors6.append([0]*300)

# %%
df5 = pd.DataFrame({'words':words5, 'vector':vectors5})
df6 = pd.DataFrame({'words':words6, 'vector':vectors6})

# %%
lle5 = locally_linear_embedding(np.matrix(df5.vector.to_list()), n_components=2, n_neighbors=12)
lle5 = lle5[0]
lle6 = locally_linear_embedding(np.matrix(df6.vector.to_list()), n_components=2, n_neighbors=12)
lle6 = lle6[0]

# %%
fig = plt.figure(figsize=(30, 30))
for i,t in enumerate(df5.words):
    x = lle5[i,0]
    y = lle5[i,1]
    plt.scatter(x, y, marker='o', color='red', s=180)
    plt.text(x+0.005, y+0.005, t, fontsize=13)
    
for i,t in enumerate(df6.words):
    x = lle6[i,0]
    y = lle6[i,1]
    plt.scatter(x, y, marker='o', color='blue', s=180)
    plt.text(x+0.005, y+0.005, t, fontsize=10)
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.title('Reduced to 2D using LLE')
plt.savefig('./LLE_w2v.png', transparent=True)
plt.show()
